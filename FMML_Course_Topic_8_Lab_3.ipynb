# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanasriBatchu/FMML_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-25 06:25:23--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  91.2MB/s    in 0.8s
#
# 2024-03-25 06:25:24 (91.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2856 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7597   1802.04502v1  We present a novel nonnegative tensor decompos...  stat
# 18648   1106.5258v1  In common-interest stochastic games all player...    cs
# 22205  1507.06350v7  Recent decades have seen an interest in predic...  stat
# 11255  1506.05173v2  We introduce single-set spectral sparsificatio...  stat
# 38961   1408.0173v2  This paper deals with the problem of reconstru...    cs
# ...             ...                                                ...   ...
# 21713   1010.2770v1  Despite the recent progress towards efficient ...  stat
# 22580  1701.06607v2  Random sinusoidal features are a popular appro...  stat
# 22610  1702.07405v1  We consider the problem of estimating a regres...  stat
# 39527  1608.00905v2  First responders are increasingly using social...    cs
# 8348   1511.06434v2  In recent years, supervised learning with conv...    cs
#
#                                                    title  year  \
# 7597                       Legendre Tensor Decomposition  2018
# 18648  Learning to Coordinate Efficiently: A Model-ba...  2011
# 22205  Admissibility of a posterior predictive decisi...  2015
# 11255  Feature Selection for Ridge Regression with Pr...  2015
# 38961        Variational Depth from Focus Reconstruction  2014
# ...                                                  ...   ...
# 21713  Online Multiple Kernel Learning for Structured...  2010
# 22580  Stable Recovery Of Sparse Vectors From Random ...  2017
# 22610  GapTV: Accurate and Interpretable Low-Dimensio...  2017
# 39527  PicHunt: Social Media Image Retrieval for Impr...  2016
# 8348   Unsupervised Representation Learning with Deep...  2015
#
#                                                 keywords
# 7597   [nonnegative, decomposition, decomposition, fa...
# 18648  [stochastic, identical, participating, coordin...
# 22205  [prediction, methodology, ubiquitously, approx...
# 11255  [introduce, sparsification, deterministic, sel...
# 38961  [reconstructing, differently, variational, inc...
# ...                                                  ...
# 21713  [efficient, structured, approaches, repeatedly...
# 22580  [sinusoidal, inference, inference, performing,...
# 22610  [estimating, regression, situation, interpreta...
# 39527  [responders, increasingly, religious, politica...
# 8348   [supervised, convolutional, applications, comp...
#
# [4284 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7597     [nonnegative, decomposition, decomposition, fa...
# 18648    [stochastic, identical, participating, coordin...
# 22205    [prediction, methodology, ubiquitously, approx...
# 11255    [introduce, sparsification, deterministic, sel...
# 38961    [reconstructing, differently, variational, inc...
#                                ...
# 35720    [resolution, reconciling, references, correspo...
# 2188     [introduce, lipschitz, convolutional, aggregat...
# 31716    [defensive, forecasting, prediction, defensive...
# 27792    [localization, anatomical, structures, prerequ...
# 2391     [andersson, interpretation, particular, constr...
# Name: keywords, Length: 5356, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8223 words.
# Out of those 4272 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f1097720-e13c-4359-8ad5-f64e498364a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f1097720-e13c-4359-8ad5-f64e498364a2")) {                    Plotly.newPlot(                        "f1097720-e13c-4359-8ad5-f64e498364a2",                        [{"x":["nonnegative","parameters","developed","divergence","minimizes","multiplicative","combination","accurately","information","empirically","reconstructed","decompositions","decomposition","reconstruct","factorizes","stochastic","coordinate","guaranteed","efficiently","reinforcement","convergence","solutions","participating","identical","algorithms","posterior","statements","prediction","methodology","distribution","predictive","potentially","ubiquitously","observable","approximating","quantities","statistical","inferential","guarantees","regularized","unsupervised","deterministic","regression","generalization","synthetic","selection","sparsification","comparable","technique","classification","experiments","experimental","randomized","introduce","comparison","reconstruction","minimization","additionally","nonsmooth","regularization","numerical","differently","simulated","alternating","presented","linearized","realistic","including","directions","variational","reconstructing","nonconvex","multipliers","classical","throughout","constrained","maintaining","incorporated","algorithm","demonstrate","projection","expensive","projections","optimization","incorporating","intermediate","decreases","alternative","reformulation","enhancement","practitioners","prevented","formulation","alternate","understand","extensive","requirements","investigation","transposition","different","integrated","simulation","iterative","surprising","performance","implemented","drawbacks","difficult","perceived","practical","introduced","searching","enhancements","published","background","principal","sensitive","conditions","detection","radiation","component","attributed","successfully","residuals","approximation","spectrometry","suppressing","outperform","assumption","plausible","employing","effective","exploited","framework","controlled","fundamental","homogenous","motivated","structural","available","nonlinear","artifacts","meanwhile","influence","trainable","weaknesses","competitive","diffusion","similarity","recovered","functions","denoising","especially","investigating","usefulness","retrieval","involving","comprehension","implement","distributions","modelling","dependency","resolution","hierarchical","represents","cognitive","independent","dependent","processes","linguistic","demonstrating","successful","completion","obtaining","theoretical","providing","guarantee","sufficiently","significant","computational","performances","parameter","reasonable","computing","nevertheless","validation","theoretically","indispensable","inferring","probability","observation","dimensional","uncorrelated","nonstationary","variances","components","graphical","structure","conditional","dimension"],"y":[8,227,140,20,16,10,97,60,578,62,20,12,64,19,0,104,22,21,141,93,104,119,5,23,506,31,6,178,53,167,42,34,1,21,11,14,126,2,57,43,124,49,92,106,100,129,0,72,210,430,495,313,20,277,114,73,72,43,2,84,68,10,45,19,147,5,62,195,32,49,13,11,13,91,14,55,34,17,673,467,34,51,23,252,41,36,8,83,4,23,10,3,73,7,68,158,46,28,2,600,40,64,63,10,722,83,20,122,9,125,93,27,9,26,54,21,37,109,290,4,81,11,79,4,112,1,3,81,54,22,29,201,24,480,30,74,1,45,55,259,38,14,15,55,26,15,82,13,113,9,181,29,91,14,20,91,32,13,57,85,38,38,91,78,40,39,106,65,72,51,26,60,27,37,159,54,25,13,196,231,32,103,26,101,16,34,37,3,27,136,41,151,2,2,1,82,42,297,61,59],"type":"bar"},{"x":["nonnegative","parameters","developed","divergence","minimizes","multiplicative","combi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4272,), (4272, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8544776119402985

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Class</span> <span style=''>Level</span> <span style=''>Bayes</span> <span style=''>Nets</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Relational</span> <span style=''>Data</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(0, 255, 0, 0.4461538461538461);'>databases</span> <span style=''>store</span> <span style=''>data</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relational</span> <span style=''>format</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>different</span> <span style=''>types</span> <span style=''>of</span> <span style=''>entities</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>links</span> <span style=''>between</span> <span style=''>the</span> <span style=''>entities</span> <span style=''>The</span> <span style=''>field</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4246575342465753);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relational</span> <span style=''>learning</span> <span style=''>(SRL)</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.4246575342465753);'>statistical</span> <span style=''>models</span> <span style=''>for</span> <span style=''>such</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>learning</span> <span style=''>class</span> <span style=''>level</span> <span style=''>or</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>which</span> <span style=''>model</span> <span style=''>the</span> <span style=''>general</span> <span style=''>database</span> <span style='background-color:rgba(255, 0, 0, 0.37349397590361444);'>statistics</span> <span style=''>over</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attributes</span> <span style=''>of</span> <span style=''>linked</span> <span style=''>objects</span> <span style=''>and</span> <span style=''>links</span> <span style=''>(eg</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>percentage</span> <span style=''>of</span> <span style=''>A</span> <span style=''>grades</span> <span style=''>given</span> <span style=''>in</span> <span style=''>computer</span> <span style=''>science</span> <span style=''>classes)</span> <span style=''>Class</span> <span style=''>level</span> <span style='background-color:rgba(255, 0, 0, 0.4246575342465753);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.5882352941176472);'>themselves</span> <span style=''>and</span> <span style=''>they</span> <span style=''>support</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>like</span> <span style=''>policy</span> <span style=''>making</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>strategic</span> <span style=''>planning</span> <span style=''>and</span> <span style=''>query</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>Most</span> <span style=''>current</span> <span style=''>SRL</span> <span style=''>methods</span> <span style=''>find</span> <span style=''>class</span> <span style=''>level</span> <span style='backg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Accelerated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>Latent</span> <span style=''>Variable</span> <span style=''>Models</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>feature</span> <span style=''>models</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>setting</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>settings</span> <span style=''>because</span> <span style=''>it</span> <span style=''>usually</span> <span style=''>requires</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proposing</span> <span style=''>features</span> <span style=''>from</span> <span style=''>some</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>In</span> <span style=''>special</span> <span style=''>cases</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integration</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tractable</span> <span style=''>we</span> <span style=''>could</span> <span style=''>sample</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assignments</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>according</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>However</span> <span style=''>this</span> <span style=''>still</span> <span style=''>may</span> <span style=''>not</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensions</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accelerate</span> <span style=''>the</span> <span style=''>mixing</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proposing</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>locations</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style=''>as</span> <span style=''>opposed</span> <span style=''>to</span> <span style=''>the</span> <span style=''>prior</span> <span style=''>This</span> <span style=''>sampling</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>for</span> <span style=''>proper</span> <span style=''>mixing</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>sampler</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attractive</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Halfspaces</span> <span style=''>and</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style=''>Random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Initialization</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>for</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>halfspaces</span> <span style=''>and</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>For</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>L</span> <span style='background-color:rgba(255, 0, 0, 0.4782608695652174);'>Lipschitz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>halfspaces</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>layer</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>that</span> <span style=''>achieve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrarily</span> <span style=''>small</span> <span style=''>excess</span> <span style=''>risk</span> <span style=''>epsilon0</span> <span style=''>The</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>in</span> <span style=''>the</span> <span style=''>input</span> <span style='background-color:rgba(255, 0, 0, 0.3551912568306011);'>dimension</span> <span style=''>d</span> <span style=''>and</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>n</span> <span style=''>but</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>in</span> <span style=''>the</span> <span style=''>quantity</span> <span style=''>(Lepsilon2)log(Lepsilon)</span> <span style=''>These</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>run</span> <span style=''>multiple</span> <span style=''>rounds</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>followed</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>steps</span> <span style=''>We</span> <span style=''>further</span> <span style=''>show</span> <span style=''>that</span> <span style=''>if</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>separable</span> <span style=''>by</span> <span style=''>some</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>with</span> <span style=''>constant</span> <span style=''>margin</span> <span style=''>gamma0</span> <span style=''>then</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>a</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Static</span> <span style=''>Gesture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recognition</span> <span style=''>using</span> <span style=''>Leap</span> <span style=''>Motion</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>report</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style=''>bartender</span> <span style=''>system</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>making</span> <span style=''>orders</span> <span style=''>in</span> <span style=''>a</span> <span style=''>bar</span> <span style=''>using</span> <span style=''>hand</span> <span style=''>gestures</span> <span style=''>The</span> <span style=''>gesture</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>system</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>using</span> <span style=''>Machine</span> <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>where</span> <span style=''>the</span> <span style=''>model</span> <span style=''>was</span> <span style=''>trained</span> <span style=''>to</span> <span style=''>classify</span> <span style=''>gestures</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collected</span> <span style=''>data</span> <span style=''>The</span> <span style=''>final</span> <span style=''>model</span> <span style=''>used</span> <span style=''>in</span> <span style=''>the</span> <span style=''>system</span> <span style=''>reached</span> <span style=''>an</span> <span style=''>average</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>95</span> <span style=''>The</span> <span style=''>system</span> <span style=''>raised</span> <span style=''>ethical</span> <span style=''>concerns</span> <span style=''>both</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>user</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>and</span> <span style=''>having</span> <span style=''>such</span> <span style=''>a</span> <span style=''>system</span> <span style=''>in</span> <span style=''>a</span> <span style=''>real</span> <span style=''>world</span> <span style=''>scenario</span> <span style=''>but</span> <span style=''>it</span> <span style=''>could</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initially</span> <span style=''>work</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complement</span> <span style=''>to</span> <span style=''>a</span> <span style=''>real</span> <span style=''>bartender</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12450679526523455)
# 	challenging (0.10127137220517317)
# 	experimental (0.13722051731696625)
# 	segmentation (0.0797895659798334)
# 	architecture (0.10390179745725558)
# 	recognition (0.11749232792634809)
# 	different (0.263042525208242)
# 	detection (0.12713722051731696)
# 	information (0.2533976326172731)
# 	convolutional (0.13853572994300745)
#
# Some Statistics words are:
# 	theoretical (0.15177234148776836)
# 	estimation (0.16774837743384924)
# 	variables (0.1432850723914129)
# 	algorithm (0.39241138292561156)
# 	stochastic (0.14428357463804292)
# 	statistical (0.15576635047428858)
# 	distribution (0.18172740888667)
# 	inference (0.19620569146280578)
# 	dimensional (0.18971542685971043)
# 	regression (0.17773339990014977)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6f398843-37e1-4a96-82a4-8686d032fe14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f398843-37e1-4a96-82a4-8686d032fe14")) {                    Plotly.newPlot(                        "6f398843-37e1-4a96-82a4-8686d032fe14",                        [{"x":["nonnegative","parameters","developed","divergence","minimizes","multiplicative","combination","accurately","information","empirically","reconstructed","decompositions","decomposition","reconstruct","factorizes","stochastic","coordinate","guaranteed","efficiently","reinforcement","convergence","solutions","participating","identical","algorithms","posterior","statements","prediction","methodology","distribution","predictive","potentially","ubiquitously","observable","approximating","quantities","statistical","inferential","guarantees","regularized","unsupervised","deterministic","regression","generalization","synthetic","selection","sparsification","comparable","technique","classification","experiments","experimental","randomized","introduce","comparison","reconstruction","minimization","additionally","nonsmooth","regularization","numerical","differently","simulated","alternating","presented","linearized","realistic","including","directions","variational","reconstructing","nonconvex","multipliers","classical","throughout","constrained","maintaining","incorporated","algorithm","demonstrate","projection","expensive","projections","optimization","incorporating","intermediate","decreases","alternative","reformulation","enhancement","practitioners","prevented","formulation","alternate","understand","extensive","requirements","investigation","transposition","different","integrated","simulation","iterative","surprising","performance","implemented","drawbacks","difficult","perceived","practical","introduced","searching","enhancements","published","background","principal","sensitive","conditions","detection","radiation","component","attributed","successfully","residuals","approximation","spectrometry","suppressing","outperform","assumption","plausible","employing","effective","exploited","framework","controlled","fundamental","homogenous","motivated","structural","available","nonlinear","artifacts","meanwhile","influence","trainable","weaknesses","competitive","diffusion","similarity","recovered","functions","denoising","especially","investigating","usefulness","retrieval","involving","comprehension","implement","distributions","modelling","dependency","resolution","hierarchical","represents","cognitive","independent","dependent","processes","linguistic","demonstrating","successful","completion","obtaining","theoretical","providing","guarantee","sufficiently","significant","computational","performances","parameter","reasonable","computing","nevertheless","validation","theoretically","indispensable","inferring","probability","observation","dimensional","uncorrelated","nonstationary","variances","components","graphical","structure","conditional","dimension","independence","characterize","formulate","describes","considerably","discovery","execution","comprehensible","heuristic","discovered","represented","approaches","improvement","generating","clustering","application","generated","heuristics","partially","activities","blockmodel","inference","exchangeable","analyzing","procedure","consistent","questions","consistently","estimation","underlying","perspective","parametric","estimated","efficient","computationally","challenging","penalization","continuous","variables","symmetric","particular","naturally","parametrization","considered","instantiation","effectively","approximated","specifically","difficulty","significantly","instantiations","complexity","resulting","techniques","appr ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	factorizes
# 	sparsification
# 	blockmodel
# 	factorisation
# 	enclosing
# 	precisions
# 	misspecified
# 	criterions
# 	barcelona
# 	suspected
# 	changepoints
# 	poisoning
# 	procrustes
# 	submodularity
# 	inhomogeneity
# 	conjugacy
# 	econometrics
# 	parsimonious
# 	multitype
# 	sociology
# Some words which never appear in Statistics papers:
# 	transposition
# 	suppressing
# 	polytrees
# 	deformation
# 	manipulation
# 	executing
# 	syntactic
# 	suspicious
# 	tampering
# 	articulated
# 	vietnamese
# 	smartphone
# 	reproduction
# 	imagevideo
# 	achievement
# 	predominant
# 	deletions
# 	multiagent
# 	recognizable
# 	gyroscope

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8423507462686567
